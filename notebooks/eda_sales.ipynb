# %% [markdown]
# # Automated EDA for sales.csv
# This notebook provides an initial exploratory data analysis (EDA) for `sales.csv`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/sales.csv')
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()
